# %% [markdown]
# # Interactive IMA Plotter
#
# This notebook provides an interactive GUI for exploring IMA magnetic measurement data.
#
# ## How to Use:
# 1. Browse to your data directory using the file chooser
# 2. Click **Load Data** to load Excel files
# 3. Use the tabs to configure filters, display options, and styling
# 4. *(Optional)* Click **Subtract Baseline** to apply baseline correction, then enable *Use Baseline Subtracted* in the Display Options tab
# 5. Click **Generate Plot** to create your visualisation

# %%
from ima_plotter.widgets import create_interactive_plotter
import warnings
warnings.filterwarnings('ignore')

# %%
# Create the interactive plotter
data_manager, plot_widgets, output = create_interactive_plotter()

# %% [markdown]
# ## Plot Configuration
#
# Use the controls below to configure your plot:

# %%
display(plot_widgets.layout)

# %% [markdown]
# ## Plot Output
#
# Your plot will appear below:

# %%
display(output)
